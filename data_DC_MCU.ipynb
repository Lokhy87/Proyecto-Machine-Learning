# %%
import pandas as pd
import itertools

# %% [markdown]
# DATA DC EXTENDED Y MCU

# %%
df_DC = pd.read_csv('./data/DC_extended_universe.csv')
df_DC.info()
df_DC.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73 entries, 0 to 72
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nombre_completo  61 non-null     object
#  1   nombre           73 non-null     object
#  2   universo         73 non-null     object
#  3   url              73 non-null     object
#  4   Intelligence     73 non-null     int64
#  5   Strength         73 non-null     int64
#  6   Speed            73 non-null     int64
#  7   Durability       73 non-null     int64
#  8   Power            73 non-null     int64
#  9   Combat           73 non-null     int64
#  10  Tier             73 non-null     int64
#  11  Tier2            9 non-null      object
#  12  superpoderes     73 non-null     object
#  13  heroe            73 non-null     object
# dtypes: int64(7), object(7)
# memory usage: 8.1+ KB
#     nombre_completo        nombre              universo  \
# ...

# %%
df_MCU = pd.read_csv('./data/MCU.csv')
df_MCU.info()
df_MCU.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176 entries, 0 to 175
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nombre_completo  161 non-null    object
#  1   nombre           176 non-null    object
#  2   universo         176 non-null    object
#  3   url              176 non-null    object
#  4   Intelligence     176 non-null    int64
#  5   Strength         176 non-null    int64
#  6   Speed            176 non-null    object
#  7   Durability       176 non-null    int64
#  8   Power            176 non-null    int64
#  9   Combat           176 non-null    int64
#  10  Tier             176 non-null    int64
#  11  Tier2            48 non-null     object
#  12  superpoderes     176 non-null    object
#  13  heroe            176 non-null    object
# dtypes: int64(6), object(8)
# memory usage: 19.4+ KB
#   nombre_completo                    nombre                   universo  \
# ...

# %%
df_marvel_dc = pd.concat([df_DC, df_MCU])
df_marvel_dc.to_csv('./data/Data_MCU_DC.csv')

# %%
df_marvel_dc.info()
df_marvel_dc.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 249 entries, 0 to 175
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nombre_completo  222 non-null    object
#  1   nombre           249 non-null    object
#  2   universo         249 non-null    object
#  3   url              249 non-null    object
#  4   Intelligence     249 non-null    int64
#  5   Strength         249 non-null    int64
#  6   Speed            249 non-null    object
#  7   Durability       249 non-null    int64
#  8   Power            249 non-null    int64
#  9   Combat           249 non-null    int64
#  10  Tier             249 non-null    int64
#  11  Tier2            57 non-null     object
#  12  superpoderes     249 non-null    object
#  13  heroe            249 non-null    object
# dtypes: int64(6), object(8)
# memory usage: 29.2+ KB
#     nombre_completo        nombre              universo  \
# ...

# %%
df_marvel_dc[df_marvel_dc['nombre'] == 'Volstagg']
# Out:
#     nombre_completo    nombre                   universo  \
# 161        Volstagg  Volstagg  Marvel Cinematic Universe
#
#                                                 url  Intelligence  Strength  \
# 161  https://www.superherodb.com/volstagg/10-14376/             0         0
#
#     Speed  Durability  Power  Combat  Tier Tier2  \
# 161     0           0      0       0     0   NaN
#
#                                           superpoderes     heroe
# 161  ['Marvel Comics', 'MCU - Marvel Cinematic Univ...  Volstagg

# %%
df_marvel_dc_names = df_marvel_dc['nombre']
df_marvel_dc_names.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 249 entries, 0 to 175
# Series name: nombre
# Non-Null Count  Dtype
# --------------  -----
# 249 non-null    object
# dtypes: object(1)
# memory usage: 3.9+ KB

# %%
df_marvel_dc_names = df_marvel_dc['nombre']
heroes = df_marvel_dc_names.tolist()
heroes
# Out:
# ['Aquaman',
#  'Ares',
#  'Atom Smasher',
#  'Batman',
#  'Black Adam',
#  'Black Canary',
#  'Black Manta',
#  'Black Mask',
#  'Bloodsport',
#  'Captain Boomerang',
#  'Cassandra Cain',
#  'Cheetah',
#  'Cyborg',
#  'Cyclone',
#  'Dark Flash',
#  'Darkseid',
#  'Deadshot',
#  'Doctor Fate',
#  'Doctor Sivana',
#  'Doomsday',
#  'El Diablo',
#  'Enchantress',
#  'Envy',
#  'Faora',
#  'Freddy Freeman',
#  'General Zod',
#  'Gluttony',
#  'Green Lantern',
#  'Harley Quinn',
#  'Hawkman',
#  'Hespera',
#  'Huntress',
#  'Incubus',
#  'Joker',
#  'Jor-El',
#  'Judomaster',
#  'Karathen',
#  'Katana',
#  'Killer Croc',
#  'King Nereus',
#  'King Shark',
#  'Lex Luthor',
#  'Lust',
#  'Mera',
#  'Mister Zsasz',
#  'Nam-Ek',
#  'Nuidis Vulko',
#  'Ocean Master',
#  'Parademon',
#  'Peacemaker',
#  'Penthesileia',
#  'Philippus',
#  'Polka-Dot Man',
#  'Queen Atlanna',
#  'Queen Hippolyta',
#  'Ratcatcher',
#  'Rick Flag',
#  'Sabbac',
#  'Savant',
#  'Shazam',
#  'Slipknot',
# ...

# %%
battle = list(itertools.combinations(heroes, 2))
battle
# Out:
# [('Aquaman', 'Ares'),
#  ('Aquaman', 'Atom Smasher'),
#  ('Aquaman', 'Batman'),
#  ('Aquaman', 'Black Adam'),
#  ('Aquaman', 'Black Canary'),
#  ('Aquaman', 'Black Manta'),
#  ('Aquaman', 'Black Mask'),
#  ('Aquaman', 'Bloodsport'),
#  ('Aquaman', 'Captain Boomerang'),
#  ('Aquaman', 'Cassandra Cain'),
#  ('Aquaman', 'Cheetah'),
#  ('Aquaman', 'Cyborg'),
#  ('Aquaman', 'Cyclone'),
#  ('Aquaman', 'Dark Flash'),
#  ('Aquaman', 'Darkseid'),
#  ('Aquaman', 'Deadshot'),
#  ('Aquaman', 'Doctor Fate'),
#  ('Aquaman', 'Doctor Sivana'),
#  ('Aquaman', 'Doomsday'),
#  ('Aquaman', 'El Diablo'),
#  ('Aquaman', 'Enchantress'),
#  ('Aquaman', 'Envy'),
#  ('Aquaman', 'Faora'),
#  ('Aquaman', 'Freddy Freeman'),
#  ('Aquaman', 'General Zod'),
#  ('Aquaman', 'Gluttony'),
#  ('Aquaman', 'Green Lantern'),
#  ('Aquaman', 'Harley Quinn'),
#  ('Aquaman', 'Hawkman'),
#  ('Aquaman', 'Hespera'),
#  ('Aquaman', 'Huntress'),
#  ('Aquaman', 'Incubus'),
#  ('Aquaman', 'Joker'),
#  ('Aquaman', 'Jor-El'),
# ...

# %%
battle_MCU_DC_df = pd.DataFrame(battle, columns = ['Heroe 1', 'Heroe 2'])
battle_MCU_DC_df.to_csv('./data/Battle_MCU_DC.csv', index = False)

# %%
battle_MCU_DC_df.info()
battle_MCU_DC_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30876 entries, 0 to 30875
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Heroe 1  30876 non-null  object
#  1   Heroe 2  30876 non-null  object
# dtypes: object(2)
# memory usage: 482.6+ KB
#    Heroe 1       Heroe 2
# 0  Aquaman          Ares
# 1  Aquaman  Atom Smasher
# 2  Aquaman        Batman
# 3  Aquaman    Black Adam
# 4  Aquaman  Black Canary

# %%
# Suponiendo que quieres encontrar todas las filas donde 'Heroe ' es 'Ares'
battle_MCU_DC_df[battle_MCU_DC_df['Heroe 1'] == 'Aquaman']
# Out:
#      Heroe 1       Heroe 2
# 0    Aquaman          Ares
# 1    Aquaman  Atom Smasher
# 2    Aquaman        Batman
# 3    Aquaman    Black Adam
# 4    Aquaman  Black Canary
# ..       ...           ...
# 243  Aquaman     Wolverine
# 244  Aquaman          Wong
# 245  Aquaman  YellowJacket
# 246  Aquaman         Yondu
# 247  Aquaman          Zeus
#
# [248 rows x 2 columns]

# %%
battle_MCU_DC_df.iloc[30860:30876]
# Out:
#               Heroe 1       Heroe 2
# 30860      White Wolf          Zeus
# 30861  Winter Soldier     Wolverine
# 30862  Winter Soldier          Wong
# 30863  Winter Soldier  YellowJacket
# 30864  Winter Soldier         Yondu
# 30865  Winter Soldier          Zeus
# 30866       Wolverine          Wong
# 30867       Wolverine  YellowJacket
# 30868       Wolverine         Yondu
# 30869       Wolverine          Zeus
# 30870            Wong  YellowJacket
# 30871            Wong         Yondu
# 30872            Wong          Zeus
# 30873    YellowJacket         Yondu
# 30874    YellowJacket          Zeus
# 30875           Yondu          Zeus

# %%
df_results = pd.read_csv('./data/Battle_MCU_DC_Results.csv')

# %%
df_results.info()
df_results.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30066 entries, 0 to 30065
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Heroe 1  30066 non-null  object
#  1   Heroe 2  30066 non-null  object
#  2   Result   30066 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 704.8+ KB
#    Heroe 1       Heroe 2  Result
# 0  Aquaman          Ares       2
# 1  Aquaman  Atom Smasher       2
# 2  Aquaman        Batman       2
# 3  Aquaman    Black Adam       2
# 4  Aquaman  Black Canary       2

# %%
df_results.iloc[30860:30876]
# Out:
# Empty DataFrame
# Columns: [Heroe 1, Heroe 2, Result]
# Index: []

# %%
df_results.iloc[500:510]
# Out:
#           Heroe 1         Heroe 2  Result
# 500  Atom Smasher     Doctor Fate       2
# 501  Atom Smasher   Doctor Sivana       2
# 502  Atom Smasher        Doomsday       2
# 503  Atom Smasher       El Diablo       2
# 504  Atom Smasher     Enchantress       2
# 505  Atom Smasher            Envy       2
# 506  Atom Smasher           Faora       2
# 507  Atom Smasher  Freddy Freeman       2
# 508  Atom Smasher     General Zod       2
# 509  Atom Smasher        Gluttony       2

# %%
# Funcion visualizar enfrentamiento concreto
def visualizar_enfrentamiento(df_results, heroe1, heroe2):
    enfrentamiento = df_results[(df_results['Heroe 1'] == heroe1) & (df_results['Heroe 2'] == heroe2)]
    if enfrentamiento.empty:
        enfrentamiento = df_results[(df_results['Heroe 1'] == heroe2) & (df_results['Heroe 2'] == heroe1)]
    
    if not enfrentamiento.empty:
        print(enfrentamiento)
    else:
        print(f"No se encontró un enfrentamiento entre {heroe1} y {heroe2}")

# %%
# Ejemplo
visualizar_enfrentamiento(df_results, 'Captain Carter (Earth 838)', 'Thor')
# Out:
#                           Heroe 1 Heroe 2  Result
# 18416  Captain Carter (Earth 838)    Thor       2

# %%
df_results[(df_results['Heroe 1'] == 'Hulk') | (df_results['Heroe 2'] == 'Hulk')]
# Out:
#             Heroe 1       Heroe 2  Result
# 127         Aquaman          Hulk       2
# 370            Ares          Hulk       2
# 612    Atom Smasher          Hulk       2
# 853          Batman          Hulk       2
# 1093     Black Adam          Hulk       2
# ...             ...           ...     ...
# 23505          Hulk     Wolverine       2
# 23506          Hulk          Wong       2
# 23507          Hulk  YellowJacket       2
# 23508          Hulk         Yondu       2
# 23509          Hulk          Zeus       2
#
# [245 rows x 3 columns]

# %% [markdown]
# Merge para crear data final

# %%
df_marvel_dc
# Out:
#       nombre_completo        nombre                   universo  \
# 0        Arthur Curry       Aquaman       DC Extended Universe
# 1                Ares          Ares       DC Extended Universe
# 2    Albert Rothstein  Atom Smasher       DC Extended Universe
# 3         Bruce Wayne        Batman       DC Extended Universe
# 4           Teth-Adam    Black Adam       DC Extended Universe
# ..                ...           ...                        ...
# 171             Logan     Wolverine  Marvel Cinematic Universe
# 172              Wong          Wong  Marvel Cinematic Universe
# 173      Darren Cross  YellowJacket  Marvel Cinematic Universe
# 174             Yondu         Yondu  Marvel Cinematic Universe
# 175              Zeus          Zeus  Marvel Cinematic Universe
#
#                                                    url  Intelligence  \
# 0        https://www.superherodb.com/aquaman/10-12533/            65
# ...

# %%
df_results
# Out:
#             Heroe 1       Heroe 2  Result
# 0           Aquaman          Ares       2
# 1           Aquaman  Atom Smasher       2
# 2           Aquaman        Batman       2
# 3           Aquaman    Black Adam       2
# 4           Aquaman  Black Canary       2
# ...             ...           ...     ...
# 30061          Wong          Zeus       2
# 30062  YellowJacket         Yondu       2
# 30063  YellowJacket          Zeus       2
# 30064         Yondu          Zeus       2
# 30065       Aquaman    Lex Luthor       1
#
# [30066 rows x 3 columns]

# %%
# Merge heroes 1
battles_merged_1 = df_results.merge(df_marvel_dc, left_on='Heroe 1', right_on='heroe', suffixes=('', '_Heroe1'))

# Merge heroes 2
battles_merged = battles_merged_1.merge(df_marvel_dc, left_on='Heroe 2', right_on='heroe', suffixes=('_Heroe1', '_Heroe2'))

# Seleccionar columnas 
battles_final_all_attributes = battles_merged[['Heroe 1', 'Heroe 2', 'Result',
                                               'universo_Heroe1', 'superpoderes_Heroe1',
                                               'Intelligence_Heroe1', 'Strength_Heroe1', 'Speed_Heroe1', 
                                               'Durability_Heroe1', 'Power_Heroe1', 'Combat_Heroe1', 
                                               'Tier_Heroe1', 'Tier2_Heroe1',
                                               'universo_Heroe2', 'superpoderes_Heroe2',
                                               'Intelligence_Heroe2', 'Strength_Heroe2', 'Speed_Heroe2', 
                                               'Durability_Heroe2', 'Power_Heroe2', 'Combat_Heroe2', 
                                               'Tier_Heroe2', 'Tier2_Heroe2']]

# %%
battles_final_all_attributes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25510 entries, 0 to 25509
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Heroe 1              25510 non-null  object
#  1   Heroe 2              25510 non-null  object
#  2   Result               25510 non-null  int64
#  3   universo_Heroe1      25510 non-null  object
#  4   superpoderes_Heroe1  25510 non-null  object
#  5   Intelligence_Heroe1  25510 non-null  int64
#  6   Strength_Heroe1      25510 non-null  int64
#  7   Speed_Heroe1         25510 non-null  object
#  8   Durability_Heroe1    25510 non-null  int64
#  9   Power_Heroe1         25510 non-null  int64
#  10  Combat_Heroe1        25510 non-null  int64
#  11  Tier_Heroe1          25510 non-null  int64
#  12  Tier2_Heroe1         4764 non-null   object
#  13  universo_Heroe2      25510 non-null  object
#  14  superpoderes_Heroe2  25510 non-null  object
# ...

# %%
df_marvel_dc[df_marvel_dc['nombre'] == 'Ronan The Accuser']
# Out:
#     nombre_completo             nombre                   universo  \
# 125           Ronan  Ronan The Accuser  Marvel Cinematic Universe
#
#                                                    url  Intelligence  \
# 125  https://www.superherodb.com/ronan-the-accuser/...            65
#
#      Strength Speed  Durability  Power  Combat  Tier Tier2  \
# 125        55    25          35     55      90     2     2
#
#                                           superpoderes              heroe
# 125  ['Berserk Mode', 'Bloodlust', 'Cold Resistance...  Ronan the Accuser

# %%
df_results[df_results['Heroe 1'] == 'Drax The Destroyer']
# Out:
#                   Heroe 1       Heroe 2  Result
# 20053  Drax The Destroyer     Ebony Maw       2
# 20054  Drax The Destroyer          Echo       2
# 20055  Drax The Destroyer           Ego       2
# 20056  Drax The Destroyer       Elektra       2
# 20057  Drax The Destroyer      Eternity       2
# ...                   ...           ...     ...
# 20189  Drax The Destroyer     Wolverine       2
# 20190  Drax The Destroyer          Wong       2
# 20191  Drax The Destroyer  YellowJacket       2
# 20192  Drax The Destroyer         Yondu       2
# 20193  Drax The Destroyer          Zeus       2
#
# [141 rows x 3 columns]

# %%
battles_final_all_attributes[battles_final_all_attributes['Heroe 2'] == 'Ronan The Accuser']
# Out:
# Empty DataFrame
# Columns: [Heroe 1, Heroe 2, Result, universo_Heroe1, superpoderes_Heroe1, Intelligence_Heroe1, Strength_Heroe1, Speed_Heroe1, Durability_Heroe1, Power_Heroe1, Combat_Heroe1, Tier_Heroe1, Tier2_Heroe1, universo_Heroe2, superpoderes_Heroe2, Intelligence_Heroe2, Strength_Heroe2, Speed_Heroe2, Durability_Heroe2, Power_Heroe2, Combat_Heroe2, Tier_Heroe2, Tier2_Heroe2]
# Index: []
#
# [0 rows x 23 columns]

# %%
# Identificar héroes únicos en el archivo de resultados de batalla
heroes_in_battles = set(df_results['Heroe 1']).union(set(df_results['Heroe 2']))

# Identificar héroes únicos en el archivo de datos de héroes
heroes_in_data = set(df_marvel_dc['heroe'])

# Identificar héroes que faltan en el archivo de datos de héroes
missing_heroes = heroes_in_battles - heroes_in_data

print("Héroes faltantes:", missing_heroes)
# Out:
# Héroes faltantes: {'Ronan The Accuser', 'Iron Man (Mk 1)', 'Wonder Woman (Armor of Asteria)', 'Ancient One (time stone)', 'Talos The Untamed', 'Drax The Destroyer', 'Korath The Pursuer', 'Loki (Keeper Of The Multiverse)', "M'baku", 'Captain Carter (Earth 838)', "G'iah", 'Sersi (uni-mind)', 'YellowJacket', 'Gorr The God Butcher', 'Jemiah The Analyzer', 'Black Bolt (Earth 838)', 'Wanda Maximoff (Pre-WandaVision)', 'Whiplash (Mark II)', 'Arishem The Judge', 'Ronan The Accuser (Power Stone)', 'Mr. Fantastic (Earth 838)'}
