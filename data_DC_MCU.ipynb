# %%
import pandas as pd
import itertools

from itertools import product

# %% [markdown]
# DATA DC EXTENDED Y MCU

# %%
# Cargar y visualizar data DC_extended_universe
df_DC = pd.read_csv('./data/DC_extended_universe.csv')
df_DC.info()
df_DC.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73 entries, 0 to 72
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nombre_completo  61 non-null     object
#  1   nombre           73 non-null     object
#  2   universo         73 non-null     object
#  3   url              73 non-null     object
#  4   Intelligence     73 non-null     int64
#  5   Strength         73 non-null     int64
#  6   Speed            73 non-null     int64
#  7   Durability       73 non-null     int64
#  8   Power            73 non-null     int64
#  9   Combat           73 non-null     int64
#  10  Tier             73 non-null     int64
#  11  Tier2            9 non-null      object
#  12  superpoderes     73 non-null     object
#  13  heroe            73 non-null     object
# dtypes: int64(7), object(7)
# memory usage: 8.1+ KB
#     nombre_completo        nombre              universo  \
# ...

# %%
# Cargar y visualizar data MCU
df_MCU = pd.read_csv('./data/MCU.csv')
df_MCU.info()
df_MCU.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175 entries, 0 to 174
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nombre_completo  160 non-null    object
#  1   nombre           175 non-null    object
#  2   universo         175 non-null    object
#  3   url              175 non-null    object
#  4   Intelligence     175 non-null    int64
#  5   Strength         175 non-null    int64
#  6   Speed            175 non-null    object
#  7   Durability       175 non-null    int64
#  8   Power            175 non-null    int64
#  9   Combat           175 non-null    int64
#  10  Tier             175 non-null    int64
#  11  Tier2            48 non-null     object
#  12  superpoderes     175 non-null    object
#  13  heroe            175 non-null    object
# dtypes: int64(6), object(8)
# memory usage: 19.3+ KB
#   nombre_completo                    nombre                   universo  \
# ...

# %%
# Crear data union DC y Marvel
df_heroes = pd.concat([df_DC, df_MCU])
#df_heroes.to_csv('./data/Data_MCU_DC.csv')

# %%
df_heroes.info()
df_heroes.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 248 entries, 0 to 174
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nombre_completo  221 non-null    object
#  1   nombre           248 non-null    object
#  2   universo         248 non-null    object
#  3   url              248 non-null    object
#  4   Intelligence     248 non-null    int64
#  5   Strength         248 non-null    int64
#  6   Speed            248 non-null    object
#  7   Durability       248 non-null    int64
#  8   Power            248 non-null    int64
#  9   Combat           248 non-null    int64
#  10  Tier             248 non-null    int64
#  11  Tier2            57 non-null     object
#  12  superpoderes     248 non-null    object
#  13  heroe            248 non-null    object
# dtypes: int64(6), object(8)
# memory usage: 29.1+ KB
#     nombre_completo        nombre              universo  \
# ...

# %%
# Visualizacion de algunos ejemplos 
df_heroes[df_heroes['nombre'] == "Shuri"]
# Out:
#     nombre_completo nombre                   universo  \
# 132           Shuri  Shuri  Marvel Cinematic Universe
#
#                                              url  Intelligence  Strength  \
# 132  https://www.superherodb.com/shuri/10-13971/            85         1
#
#     Speed  Durability  Power  Combat  Tier Tier2  \
# 132     6          15     15      30     1   NaN
#
#                                           superpoderes  heroe
# 132  ['Intelligence', 'Peak Human Condition', 'Stam...  Shuri

# %%
# Creo data con solo nombres
df_heroes_names = df_heroes['nombre']
df_heroes_names.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 248 entries, 0 to 174
# Series name: nombre
# Non-Null Count  Dtype
# --------------  -----
# 248 non-null    object
# dtypes: object(1)
# memory usage: 3.9+ KB

# %%
# Paso a lista 
heroes = df_heroes_names.tolist()
#heroes

# %%
battle = list(itertools.combinations(heroes, 2))
#battle

# %%
battle_df = pd.DataFrame(battle, columns = ['Heroe 1', 'Heroe 2'])
# battle_df.to_csv('./data/Battle_MCU_DC.csv', index = False)

# %% [markdown]
# NUEVO DATA ENFRENTAMIENTOS

# %%
heroes = df_heroes['heroe'].unique()
#heroes

# %%
combinaciones_posibles = list(product(heroes, repeat=2))
#combinaciones_posibles

# %%
# Crear el DataFrame 
df_battle = pd.DataFrame(combinaciones_posibles, columns = ['Heroe 1', 'Heroe 2'])

# %%
df_battle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61009 entries, 0 to 61008
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Heroe 1  61009 non-null  object
#  1   Heroe 2  61009 non-null  object
# dtypes: object(2)
# memory usage: 953.4+ KB

# %%
df_battle.head()
# Out:
#    Heroe 1       Heroe 2
# 0  Aquaman       Aquaman
# 1  Aquaman          Ares
# 2  Aquaman  Atom Smasher
# 3  Aquaman        Batman
# 4  Aquaman    Black Adam

# %%
# Comprobar no hayan duplicados 
df_battle[df_battle.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Heroe 1, Heroe 2]
# Index: []

# %%
# Quitar enfrentamientos entre si mismos
df_sin_autoenfrentamientos = df_battle[df_battle['Heroe 1'] != df_battle['Heroe 2']]
df_sin_autoenfrentamientos
# Out:
#        Heroe 1         Heroe 2
# 1      Aquaman            Ares
# 2      Aquaman    Atom Smasher
# 3      Aquaman          Batman
# 4      Aquaman      Black Adam
# 5      Aquaman    Black Canary
# ...        ...             ...
# 61003    Yondu      White Wolf
# 61004    Yondu  Winter Soldier
# 61005    Yondu       Wolverine
# 61006    Yondu            Wong
# 61007    Yondu    Yellowjacket
#
# [60762 rows x 2 columns]

# %%
df_sin_autoenfrentamientos.to_csv('./data/Face_to_face.csv', index = False)

# %%
df_sin_autoenfrentamientos.info()
df_sin_autoenfrentamientos.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60762 entries, 1 to 61007
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Heroe 1  60762 non-null  object
#  1   Heroe 2  60762 non-null  object
# dtypes: object(2)
# memory usage: 1.4+ MB
#    Heroe 1       Heroe 2
# 1  Aquaman          Ares
# 2  Aquaman  Atom Smasher
# 3  Aquaman        Batman
# 4  Aquaman    Black Adam
# 5  Aquaman  Black Canary

# %%
df_new_results = pd.read_csv('./data/nuevo_battle_result.csv')
df_new_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59292 entries, 0 to 59291
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Heroe 1              59292 non-null  object
#  1   Heroe 2              59292 non-null  object
#  2   Resultado_Comics     59292 non-null  int64
#  3   Resultado_Peliculas  59292 non-null  int64
#  4   Resultado_Combinado  59292 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 2.3+ MB

# %%
df_new_results.head()
# Out:
#         Heroe 1        Heroe 2  Resultado_Comics  Resultado_Peliculas  \
# 0          Envy    Ancient One                 2                    1
# 1       Warlock     Judomaster                 1                    2
# 2      Deadshot  Corvus Glaive                 2                    1
# 3   Doctor Fate        Makkari                 2                    1
# 4  Yellowjacket     Black Adam                 2                    1
#
#    Resultado_Combinado
# 0                    2
# 1                    1
# 2                    2
# 3                    2
# 4                    2

# %%
# Funcion visualizar enfrentamiento concreto
def visualizar_enfrentamiento(df_new_results, heroe1, heroe2):
    enfrentamiento = df_new_results[(df_new_results['Heroe 1'] == heroe1) & (df_new_results['Heroe 2'] == heroe2)]
    if enfrentamiento.empty:
        enfrentamiento = df_new_results[(df_new_results['Heroe 1'] == heroe2) & (df_new_results['Heroe 2'] == heroe1)]
    
    if not enfrentamiento.empty:
        print(enfrentamiento)
    else:
        print(f"No se encontró un enfrentamiento entre {heroe1} y {heroe2}")

# %%
# Ejemplo
visualizar_enfrentamiento(df_new_results, 'Envy', 'Judomaster')
# Out:
#       Heroe 1     Heroe 2  Resultado_Comics  Resultado_Peliculas  \
# 39266    Envy  Judomaster                 2                    1
#
#        Resultado_Combinado
# 39266                    2

# %%
df_new_results[(df_new_results['Heroe 1'] == 'Yondu') | (df_new_results['Heroe 2'] == 'Yondu')]
# Out:
#                        Heroe 1               Heroe 2  Resultado_Comics  \
# 100                      Yondu  Loki (Variant L1130)                 1
# 246            Agatha Harkness                 Yondu                 2
# 375                      Yondu            Black Mask                 2
# 432           Proxima Midnight                 Yondu                 2
# 622    Black Panther (Variant)                 Yondu                 2
# ...                        ...                   ...               ...
# 58794                    Yondu                 Okoye                 1
# 58858                    Yondu              Heimdall                 2
# 58868                   Fenris                 Yondu                 2
# 58930                    Yondu              Darkseid                 2
# 59192              Abomination                 Yondu                 1
#
#        Resultado_Peliculas  Resultado_Combinado
# 100                      2                    1
# ...

# %%
df_new_results.iloc[500:510]
# Out:
#                Heroe 1            Heroe 2  Resultado_Comics  \
# 500         Peacemaker           Kid Loki                 1
# 501  Hawkeye (Variant)             Fenris                 2
# 502              Groot             Vision                 2
# 503          Star-Lord           Huntress                 2
# 504          Nick Fury          Parademon                 2
# 505       Yellowjacket    Thor (Awakened)                 2
# 506           Karathen  Captain Boomerang                 2
# 507             Savant         Spider-Man                 1
# 508           Deathlok                Ayo                 1
# 509    Captain America         Killmonger                 1
#
#      Resultado_Peliculas  Resultado_Combinado
# 500                    2                    1
# 501                    1                    2
# 502                    1                    2
# 503                    1                    2
# 504                    1                    2
# ...

# %% [markdown]
# DATA BATTLE_RESULTS NUEVO

# %%
# df_results = pd.read_csv('./data/Battle_results.csv')
# df_results.info()
# df_results.head()

# %% [markdown]
# Merge para crear data final

# %%
df_heroes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 248 entries, 0 to 174
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nombre_completo  221 non-null    object
#  1   nombre           248 non-null    object
#  2   universo         248 non-null    object
#  3   url              248 non-null    object
#  4   Intelligence     248 non-null    int64
#  5   Strength         248 non-null    int64
#  6   Speed            248 non-null    object
#  7   Durability       248 non-null    int64
#  8   Power            248 non-null    int64
#  9   Combat           248 non-null    int64
#  10  Tier             248 non-null    int64
#  11  Tier2            57 non-null     object
#  12  superpoderes     248 non-null    object
#  13  heroe            248 non-null    object
# dtypes: int64(6), object(8)
# memory usage: 29.1+ KB

# %%
df_new_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59292 entries, 0 to 59291
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Heroe 1              59292 non-null  object
#  1   Heroe 2              59292 non-null  object
#  2   Resultado_Comics     59292 non-null  int64
#  3   Resultado_Peliculas  59292 non-null  int64
#  4   Resultado_Combinado  59292 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 2.3+ MB

# %%
# Verificar las dimensiones del dataframe original
original_entries = len(df_new_results)

# Verificar si hay duplicados en las columnas de héroes en los datos de atributos
unique_heroes_attributes = df_heroes['nombre'].nunique()

# Verificar cuántos héroes del nuevo_battle_results no tienen coincidencia en el data_mcu_dc
heroe_1_not_in_attributes = df_new_results[~df_new_results['Heroe 1'].isin(df_heroes['nombre'])].shape[0]
heroe_2_not_in_attributes = df_new_results[~df_new_results['Heroe 2'].isin(df_heroes['nombre'])].shape[0]

# Resultados
original_entries, unique_heroes_attributes, heroe_1_not_in_attributes, heroe_2_not_in_attributes
# Out:
# (59292, 244, 5747, 5758)

# %%
# Identificar héroes duplicados en el dataframe original data_mcu_dc
duplicate_heroes = df_heroes[df_heroes.duplicated(subset=['nombre'], keep=False)].sort_values(by='nombre')

# Mostrar los héroes duplicados
duplicate_heroes[['nombre_completo', 'nombre', 'universo']]
# Out:
#       nombre_completo         nombre                   universo
# 13           T'Challa  Black Panther  Marvel Cinematic Universe
# 14              Shuri  Black Panther  Marvel Cinematic Universe
# 15   Natasha Romanoff    Black Widow  Marvel Cinematic Universe
# 16      Yelena Belova    Black Widow  Marvel Cinematic Universe
# 54       Clint Barton        Hawkeye  Marvel Cinematic Universe
# 55        Kate Bishop        Hawkeye  Marvel Cinematic Universe
# 72               Zeus           Zeus       DC Extended Universe
# 174              Zeus           Zeus  Marvel Cinematic Universe

# %%
# Verificar si hay duplicados exactos en el DataFrame completo
exact_duplicates = df_heroes[df_heroes.duplicated()]

# Verificar si hay duplicados en base al nombre del héroe
name_duplicates = df_heroes[df_heroes.duplicated(subset=['nombre'], keep=False)]

# Mostrar el número de duplicados exactos y los duplicados por nombre
exact_duplicates_count = exact_duplicates.shape[0]
name_duplicates_count = name_duplicates.shape[0]

exact_duplicates_count, name_duplicates_count, name_duplicates[['nombre_completo', 'nombre', 'universo']]
# Out:
# (0,
#  8,
#        nombre_completo         nombre                   universo
#  72               Zeus           Zeus       DC Extended Universe
#  13           T'Challa  Black Panther  Marvel Cinematic Universe
#  14              Shuri  Black Panther  Marvel Cinematic Universe
#  15   Natasha Romanoff    Black Widow  Marvel Cinematic Universe
#  16      Yelena Belova    Black Widow  Marvel Cinematic Universe
#  54       Clint Barton        Hawkeye  Marvel Cinematic Universe
#  55        Kate Bishop        Hawkeye  Marvel Cinematic Universe
#  174              Zeus           Zeus  Marvel Cinematic Universe)

# %%
# Eliminar duplicados en base al nombre del héroe
data_mcu_dc_unique = df_heroes.drop_duplicates(subset=['nombre'], keep='first')

# Verificar el número de héroes únicos después de eliminar duplicados
unique_heroes_corrected = data_mcu_dc_unique['nombre'].nunique()

# Realizar la combinación interna con el dataframe sin duplicados
# Merge attributes for Heroe 1
battle_results_merged_corrected = df_new_results.merge(data_mcu_dc_unique, left_on='Heroe 1', right_on='nombre', how='inner')

# Rename columns to specify Heroe 1 attributes
battle_results_merged_corrected.rename(columns={
    'universo': 'Universe_1',
    'Intelligence': 'Intelligence_1',
    'Strength': 'Strength_1',
    'Speed': 'Speed_1',
    'Durability': 'Durability_1',
    'Power': 'Power_1',
    'Combat': 'Combat_1',
    'superpoderes': 'Superpowers_1',
    'Tier': 'Tier_1',
    'Tier2': 'Tier2_1'
}, inplace=True)

# Drop the extra 'nombre' column
battle_results_merged_corrected.drop(columns=['nombre', 'nombre_completo', 'url', 'heroe'], inplace=True)

# Merge attributes for Heroe 2
battle_results_merged_corrected = battle_results_merged_corrected.merge(data_mcu_dc_unique, left_on='Heroe 2', right_on='nombre', how='inner')

# Rename columns to specify Heroe 2 attributes
battle_results_merged_corrected.rename(columns={
    'universo': 'Universe_2',
    'Intelligence': 'Intelligence_2',
    'Strength': 'Strength_2',
    'Speed': 'Speed_2',
    'Durability': 'Durability_2',
    'Power': 'Power_2',
    'Combat': 'Combat_2',
    'superpoderes': 'Superpowers_2',
    'Tier': 'Tier_2',
    'Tier2': 'Tier2_2'
}, inplace=True)

# Drop the extra 'nombre' column
battle_results_merged_corrected.drop(columns=['nombre', 'nombre_completo', 'url', 'heroe'], inplace=True)

# %%
battle_results_merged_corrected['Resultado_Peliculas'].value_counts()
# Out:
# Resultado_Peliculas
# 1    24293
# 2    24024
# 0        2
# Name: count, dtype: int64

# %%
battle_results_merged_corrected['Resultado_Comics'].head(50)
# Out:
# 0     2
# 1     1
# 2     2
# 3     1
# 4     1
# 5     1
# 6     1
# 7     2
# 8     2
# 9     2
# 10    1
# 11    2
# 12    1
# 13    1
# 14    1
# 15    2
# 16    2
# 17    1
# 18    1
# 19    1
# 20    1
# 21    2
# 22    2
# 23    1
# 24    2
# 25    1
# 26    2
# 27    2
# 28    2
# 29    1
# 30    1
# 31    2
# 32    1
# 33    2
# 34    2
# 35    2
# 36    1
# 37    2
# 38    2
# 39    2
# 40    1
# 41    2
# 42    1
# 43    2
# 44    1
# 45    1
# 46    2
# 47    1
# 48    2
# 49    2
# Name: Resultado_Comics, dtype: int64

# %%
battle_results_merged_corrected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48319 entries, 0 to 48318
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Heroe 1              48319 non-null  object
#  1   Heroe 2              48319 non-null  object
#  2   Resultado_Comics     48319 non-null  int64
#  3   Resultado_Peliculas  48319 non-null  int64
#  4   Resultado_Combinado  48319 non-null  int64
#  5   Universe_1           48319 non-null  object
#  6   Intelligence_1       48319 non-null  int64
#  7   Strength_1           48319 non-null  int64
#  8   Speed_1              48319 non-null  object
#  9   Durability_1         48319 non-null  int64
#  10  Power_1              48319 non-null  int64
#  11  Combat_1             48319 non-null  int64
#  12  Tier_1               48319 non-null  int64
#  13  Tier2_1              10640 non-null  object
#  14  Superpowers_1        48319 non-null  object
# ...

# %%
battle_results_merged_corrected[battle_results_merged_corrected['Heroe 1'] == "Aquaman"]
# Out:
#        Heroe 1                      Heroe 2  Resultado_Comics  \
# 137    Aquaman                  Ancient One                 2
# 351    Aquaman                          Kro                 2
# 564    Aquaman                  General Zod                 2
# 783    Aquaman                   Ratcatcher                 2
# 1002   Aquaman                     Superman                 2
# ...        ...                          ...               ...
# 47375  Aquaman                         Envy                 1
# 47590  Aquaman                         Ajak                 2
# 47810  Aquaman                       Vision                 2
# 48024  Aquaman                       Batman                 2
# 48242  Aquaman  Star-Lord (Celestial Power)                 2
#
#        Resultado_Peliculas  Resultado_Combinado            Universe_1  \
# 137                      1                    2  DC Extended Universe
# 351                      1                    2  DC Extended Universe
# ...

# %%
battle_results_merged_corrected.head()
# Out:
#          Heroe 1      Heroe 2  Resultado_Comics  Resultado_Peliculas  \
# 0           Envy  Ancient One                 2                    1
# 1        Warlock  Ancient One                 1                    2
# 2       Deadshot  Ancient One                 2                    1
# 3    Doctor Fate  Ancient One                 1                    2
# 4  Cull Obsidian  Ancient One                 1                    2
#
#    Resultado_Combinado                 Universe_1  Intelligence_1  Strength_1  \
# 0                    2       DC Extended Universe              65          65
# 1                    1  Marvel Cinematic Universe              45          50
# 2                    2       DC Extended Universe              60           1
# 3                    1       DC Extended Universe              85          75
# 4                    1  Marvel Cinematic Universe              60          75
#
#   Speed_1  Durability_1  ...                 Universe_2  Intelligence_2  \
# ...

# %% [markdown]
# Data final para trabajar

# %%
battle_results_merged_corrected.to_csv('./data/Data_final_MCU_vs_DC.csv', index = False)

# %%
battle_results_merged_corrected.columns
# Out:
# Index(['Heroe 1', 'Heroe 2', 'Resultado_Comics', 'Resultado_Peliculas',
#        'Resultado_Combinado', 'Universe_1', 'Intelligence_1', 'Strength_1',
#        'Speed_1', 'Durability_1', 'Power_1', 'Combat_1', 'Tier_1', 'Tier2_1',
#        'Superpowers_1', 'Universe_2', 'Intelligence_2', 'Strength_2',
#        'Speed_2', 'Durability_2', 'Power_2', 'Combat_2', 'Tier_2', 'Tier2_2',
#        'Superpowers_2'],
#       dtype='object')

# %% [markdown]
# Face to Face with results

# %%
df_heroes
# Out:
#       nombre_completo        nombre                   universo  \
# 0        Arthur Curry       Aquaman       DC Extended Universe
# 1                Ares          Ares       DC Extended Universe
# 2    Albert Rothstein  Atom Smasher       DC Extended Universe
# 3         Bruce Wayne        Batman       DC Extended Universe
# 4           Teth-Adam    Black Adam       DC Extended Universe
# ..                ...           ...                        ...
# 170             Logan     Wolverine  Marvel Cinematic Universe
# 171              Wong          Wong  Marvel Cinematic Universe
# 172      Darren Cross  YellowJacket  Marvel Cinematic Universe
# 173             Yondu         Yondu  Marvel Cinematic Universe
# 174              Zeus          Zeus  Marvel Cinematic Universe
#
#                                                    url  Intelligence  \
# 0        https://www.superherodb.com/aquaman/10-12533/            65
# ...

# %%
results = pd.read_csv('./data/Face_to_face_with_results.csv')
results
# Out:
#        Heroe 1         Heroe 2  Resultado
# 0      Aquaman            Ares          1
# 1      Aquaman    Atom Smasher          0
# 2      Aquaman          Batman          1
# 3      Aquaman      Black Adam          1
# 4      Aquaman    Black Canary          0
# ...        ...             ...        ...
# 60757    Yondu      White Wolf          1
# 60758    Yondu  Winter Soldier          1
# 60759    Yondu       Wolverine          1
# 60760    Yondu            Wong          1
# 60761    Yondu    Yellowjacket          1
#
# [60762 rows x 3 columns]

# %%
# Identificar héroes duplicados en el dataframe original data_mcu_dc
duplicate_heroes = df_heroes[df_heroes.duplicated(subset=['nombre'], keep=False)].sort_values(by='nombre')

# Mostrar los héroes duplicados
duplicate_heroes[['nombre_completo', 'nombre', 'universo']]
# Out:
#       nombre_completo         nombre                   universo
# 13           T'Challa  Black Panther  Marvel Cinematic Universe
# 14              Shuri  Black Panther  Marvel Cinematic Universe
# 15   Natasha Romanoff    Black Widow  Marvel Cinematic Universe
# 16      Yelena Belova    Black Widow  Marvel Cinematic Universe
# 54       Clint Barton        Hawkeye  Marvel Cinematic Universe
# 55        Kate Bishop        Hawkeye  Marvel Cinematic Universe
# 72               Zeus           Zeus       DC Extended Universe
# 174              Zeus           Zeus  Marvel Cinematic Universe

# %%
# Eliminar duplicados en base al nombre del héroe
data_mcu_dc_unique = df_heroes.drop_duplicates(subset=['nombre'], keep='first')

# Verificar el número de héroes únicos después de eliminar duplicados
unique_heroes_corrected = data_mcu_dc_unique['nombre'].nunique()

# Realizar la combinación interna con el dataframe sin duplicados
# Merge attributes for Heroe 1
battle_results_merged_corrected = results.merge(data_mcu_dc_unique, left_on='Heroe 1', right_on='nombre', how='inner')

# Rename columns to specify Heroe 1 attributes
battle_results_merged_corrected.rename(columns={
    'universo': 'Universe_1',
    'Intelligence': 'Intelligence_1',
    'Strength': 'Strength_1',
    'Speed': 'Speed_1',
    'Durability': 'Durability_1',
    'Power': 'Power_1',
    'Combat': 'Combat_1',
    'superpoderes': 'Superpowers_1',
    'Tier': 'Tier_1',
    'Tier2': 'Tier2_1'
}, inplace=True)

# Drop the extra 'nombre' column
battle_results_merged_corrected.drop(columns=['nombre', 'nombre_completo', 'url', 'heroe'], inplace=True)

# Merge attributes for Heroe 2
battle_results_merged_corrected = battle_results_merged_corrected.merge(data_mcu_dc_unique, left_on='Heroe 2', right_on='nombre', how='inner')

# Rename columns to specify Heroe 2 attributes
battle_results_merged_corrected.rename(columns={
    'universo': 'Universe_2',
    'Intelligence': 'Intelligence_2',
    'Strength': 'Strength_2',
    'Speed': 'Speed_2',
    'Durability': 'Durability_2',
    'Power': 'Power_2',
    'Combat': 'Combat_2',
    'superpoderes': 'Superpowers_2',
    'Tier': 'Tier_2',
    'Tier2': 'Tier2_2'
}, inplace=True)

# Drop the extra 'nombre' column
battle_results_merged_corrected.drop(columns=['nombre', 'nombre_completo', 'url', 'heroe'], inplace=True)

# %%
battle_results_merged_corrected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49506 entries, 0 to 49505
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Heroe 1         49506 non-null  object
#  1   Heroe 2         49506 non-null  object
#  2   Resultado       49506 non-null  int64
#  3   Universe_1      49506 non-null  object
#  4   Intelligence_1  49506 non-null  int64
#  5   Strength_1      49506 non-null  int64
#  6   Speed_1         49506 non-null  object
#  7   Durability_1    49506 non-null  int64
#  8   Power_1         49506 non-null  int64
#  9   Combat_1        49506 non-null  int64
#  10  Tier_1          49506 non-null  int64
#  11  Tier2_1         10878 non-null  object
#  12  Superpowers_1   49506 non-null  object
#  13  Universe_2      49506 non-null  object
#  14  Intelligence_2  49506 non-null  int64
#  15  Strength_2      49506 non-null  int64
#  16  Speed_2         49506 non-null  object
# ...

# %%
pip install streamlit
# Out:
# ...
#   Obtaining dependency information for streamlit from https://files.pythonhosted.org/packages/c6/51/f140402202af6ce1bf747243f66415c5eb2f43ba2e2ac419a7e855d20673/streamlit-1.36.0-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for altair<6,>=4.0 from https://files.pythonhosted.org/packages/46/30/2118537233fa72c1d91a81f5908a7e843a6601ccc68b76838ebc4951505f/altair-5.3.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for blinker<2,>=1.0.0 from https://files.pythonhosted.org/packages/bb/2a/10164ed1f31196a2f7f3799368a821765c62851ead0e630ab52b8e14b4d0/blinker-1.8.2-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for cachetools<6,>=4.0 from https://files.pythonhosted.org/packages/04/e6/a1551acbaa06f3e48b311329828a34bc9c51a8cfaecdeb4d03c329a1ef85/cachetools-5.4.0-py3-none-any.whl.metadata
# ...
